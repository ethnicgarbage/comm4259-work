# %% [markdown]
# # Lab 1 Jupyter Notebook Tutorial
# ### COMM 4522 <br> <i>Business Analytics with Python</i>
#
# © Jingjing Li- Ask for permission for using/quoting: jingjing.li@virginia.edu

# %% [markdown]
# ## Lab Prep
# * If you would like to see my screen on your computer, you can use web browser to login to Zoom, turn off the speaker and mute yourself.
#     - 11:00 am section: https://mcintire.zoom.us/j/95993311893?pwd=NmabjMgwCFyKkxzib3qMFahEDkkaSI.1
#     - 2:00 pm section: https://mcintire.zoom.us/j/97629389481?pwd=GA37uPdbfC0154k4M3n17SGf6qaYCg.1
#
# ## Lab Rules
# * Raise hands for questions
# * Be prepared to share your screen for Q & A or exercises

# %% [markdown]
# ## Create Your First Jupyter Notebook

# %% [markdown]
# <div style="background-color: #fff3cd; color: #856404; border: 1px solid #ffeeba; padding: 15px; border-radius: 4px;">
# <b>Note: What is Jupyter Notebooks?</b><br>
#     Jupyter is a web-based interactive development environment that supports multiple programming languages, however most commonly used with the Python programming language.
#     A Jupyter Notebook is a powerful tool for interactively developing and presenting Data Science projects. Jupyter Notebooks integrate your code and its output into a single document. That document will contain the text, mathematical equations, and visualisations that the code produces directly in the same page.
# <br><br>
# The interactive environment that Jupyter provides enables students, scientists, and researchers to create reproducible analysis and formulate a story within a single document.
#
# </div>

# %% [markdown]
# ###  From Launcher
# - On the Launcher page, select "Python 3" Kernel under Notebook
#
# ![image.png](attachment:877cdce3-2ae3-481e-851d-6b7e6491f133.png)
# ###  From JupyterLab menu
# - Click File-> New -> Notebook
#
#   ![image.png](attachment:bfe24da0-50f3-421c-888b-365139ac878e.png)

# %% [markdown]
# ### Verify the kernel
# - Go to the top-right corner of the notebook and make sure kernel is selected as  **Python 3**

# %% [markdown]
# <div style="background-color: #fff3cd; color: #856404; border: 1px solid #ffeeba; padding: 15px; border-radius: 4px;">
# <b>Note: Supporting Languages for Jupyter Notebook?</b><br>
#  you should know that "Jupyter" is a loose acronym meaning Julia, Python, and R. These programming languages were the first target languages of the Jupyter application, but nowadays, the notebook technology also supports many other languages.
#
# </div>

# %% [markdown]
# ### JupyterLab Menu & Task Bar
# #### Menu
#
# The menu bar at the top of JupyterLab has top-level menus that expose actions available in JupyterLab with their keyboard shortcuts. The default menus are:
#
# * **File:** actions related to files and directories
# * **Edit:** actions related to editing documents and other activities
# * **View:** actions that alter the appearance of JupyterLab
# * **Run:** actions for running code in different activities such as notebooks and code consoles
# * **Kernel:** actions for managing kernels, which are separate processes for running code
# * **Tabs:** a list of the open documents and activities in the dock panel
# * **Settings:** common settings and an advanced settings editor
# * **Help:** a list of JupyterLab and kernel help links
#
# The first menu is the File menu. In it, you can create a new Notebook or open a preexisting one. This is also where you would go to rename a Notebook. The most important items under File are the **Save Notebook**, **Revert Notebook to Checkpoint**, **Download**, and **Export Notebook As** and  option.

# %% [markdown]
# #### Task bar
# The task bar include common actions. Hover through each icon to understand what it does.
#
# ![image.png](attachment:11f2598c-e33f-48d3-b6e0-556a5480a8ab.png)

# %% [markdown]
# ### Cell
#
# A **cell** is a container for code to be displayed or text be shown in the cell.
# - A **code cell** contains code and will be executed by the notebook's kernel, the output will be displayed below the cell
#
# - A **markdown cell** shows text that can be formatted by Markdown language
#
#
# We can differentiate the type of cell by looking at the left side.
# if empty, it is a markdown cell.
# If there is a **[ ]**, it is a code cell.
# Number inside **[ ]** means the executed order in the kernel. For example, **[1]** means the first cell be executed.
#
# ![image.png](attachment:14428709-e3d1-4477-ac8c-3c31e57e2802.png)

# %% [markdown]
# #### Create first markdown cell
# * Click + in the task bar
#
# ![image.png](attachment:59de8529-2188-49f8-a6fc-fdbbb424b988.png)
#
# * In the rightmost dropdown menu, select “Markdown”
#
# ![image.png](attachment:3c4dd01f-c642-4f83-866a-9dfe1a275de8.png)
#
# * Notice the “[ ]: ” disappeared
# * Type “This is my first markdown!”
# * Press ctrl + Enter to run the cell

# %% [markdown]
# #### Create first code cell
# * Click + in the task bar
#
# ![image.png](attachment:417406aa-1e47-46b8-830e-475f139290c4.png)
#
#
# * In the empty cell, type in the code
# ```python
# print("Hello World!")
# ```
#
# * Press "ctrl + Enter" to run the code.
# * You should see a sentence "Hello World!" displayed below the cell.

# %% [markdown]
# #### Save your notebook
# Jupyter Notebook files are saved as you go. They will exist in your directory as a JSON file with the extension **.ipynb**. If you want to rename the file, click **"File"** and then choose **"Rename"** or click **"Untitled"** in the top left directly change the file name

# %% [markdown]
# #### Export your notebook in other format
# You can also export Jupyter Notebooks in other formats, such as **HTML**. To do so, go to the File menu, scroll down to **"Export Notebook As"** and select the type of file you’re looking for.
#
# ![image.png](attachment:77e02381-f9b9-43aa-bdc9-d1baa0dfa265.png)

# %% [markdown]
# <div style="background-color: #daffcd; border-left: 5px solid #b5ffc6; padding: 15px; margin-bottom: 20px; border-radius: 4px;">
# <b>Exercise: Create a "Hello World" Notebook </b><br>
# Following the instructions above and create a notebook with one cell that prints "Hello World!". Save the notebook and download it as a "HTML" file.
#
# </div>

# %% [markdown]
# ## Interact with Jupyter Notebook

# %% [markdown]
# ### Edit Mode vs. Command Mode
# Jupyter notebooks contains an edit and a command mode. The mode is easily identifiable by the color of the cell border.
# - Blue = <b>Edit Mode.
#
# ![image.png](attachment:32efed7b-655d-4a5c-9d2a-388a296d63b1.png)
#
# When a cell is in edit mode, you can type into the cell, like a normal text editor.
# <br>Edit mode can be entered by pressing ```Enter``` or using the mouse to click on a cell’s editor area.
#
# - Grey = <b>Command Mode.
#
# ![image.png](attachment:a31f5b22-d501-4490-85fa-2f03d957c66c.png)
#
# When you are in command mode, you are able to edit the notebook as a whole, but not type into individual cells. Most importantly, in command mode, the keyboard is mapped to a set of shortcuts that let you perform notebook and cell actions efficiently.
# <br><font color='red'>Don’t try to type into a cell in command mode; unexpected things will happen!</font>
# <br>Command Mode can be entered by pressing ```ESC``` on your keyboard.

# %% [markdown]
# 1. <mark>Shift + Enter</mark> Run current cell and select below
# 2. <mark>Ctrl + Enter</mark> Run current cell
# 3. <mark>a</mark> or <mark>b</mark> to insert cell above or below
# 4. <mark>dd</mark> can delete the current cell
# 5. <mark>m</mark> can transform code cell to **Markdown**
# 6. <mark>y</mark> can convert cell to **code**
# 7. <mark>x</mark> can cut the current cell
# 8. <mark>c</mark> can copy the current cell
# 9. <mark>v</mark> can paste cell below
# 10. <mark>shift m </mark> can merge the selected cells
# 11. <mark>Ctrl + Shift + - </mark> split the active cell at the cursorCtrl + Shift + - split the active cell at the cursor

# %% [markdown]
# <div class="alert alert-warning">
# <b>JupyterLab Tutorial</b><br>
#     You can watch this video to understand the functionalities of
#     <a href = "https://youtu.be/A5YyoCKxEOU">JupyterLab </a>
# </div>

# %% [markdown]
# ## Code Cells
#
# **Code cells allow you to enter and run code.** Code is run in a separate process called the **Kernel**.
#
#
# ### Kernels, Variables, and Environment
#
# A notebook kernel is a “computational engine” that executes the code contained in a Notebook document. There are kernels for various programming languages, however we are solely using the python kernel which executes python code.
#
# When a notebook is opened, the associated kernel is automatically launched for our convenience.

# %%
### This is python
print("This is a python code cell")
# Out:
# This is a python code cell

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# A kernel is the back-end of our notebook which not only executes our python code, but stores our initialized variables.

# %%
### For example, lets initialize variable x

x = 1738

print("x has been set to " + str(x))
# Out:
# x has been set to 1738

# %%
### Print x

print(x)
# Out:
# 1738

# %% [markdown]
# A kernel could be interruptted or restarted. We can restart the kernel by clicking **"Kernel"** then **"Restart"**. Once the kernel is restarted, what we executed before will not exist, and the first executed cell will be **[1]**.
#
# Issues arrise when we restart our kernel and attempt to run code with variables that have not been reinitialized.
#
# If the kernel is reset, make sure to rerun code where variables are intialized.

# %%
## We can also run code that accepts input

name = input("What is your name? ")

print("The name you entered is " + name)
# Out:
# The name you entered is

# %% [markdown]
# It is important to note that Jupyter Notebooks have in-line cell execution.  This means that a prior executing cell must complete its operations prior to another cell being executed.  A cell still being executing is indicated by the [*] on the left-hand side of the cell.

# %%
print("This won't print until all prior cells have finished executing.")
# Out:
# This won't print until all prior cells have finished executing.

# %% [markdown]
# ## Markdown Cells
# Markdown is a markup language that uses plain text formatting syntax.  This means that we can modify the formatting our text with the use of various symbols on our keyboard as indicators.
#
# Some examples include:
#
# * <b>Headers
# * <b>Text modifications such as italics and bold
# * <b>Ordered and Unordered lists
# * <b>Links
# * <b>Tables
# * <b>Images
#
#
# Now I'll showcase some examples of how this formatting is done (**double click the markdown cell to view the source code**):

# %% [markdown]
# ### 5.1 Header

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %% [markdown]
# ### 5.2 bullet points

# %% [markdown]
# - bullet 1
#     - text
# - bullet 2
#     - text

# %% [markdown]
# ### 5.3 Highlighting
# 1. code highlighting
#
#
#
# ```python
#
# print("H")
# ```
#
#
# ```python
# print(x)
# ```
#
# This is how print function will work in python:
# ```python
# x = 18
# print(x)
# print("Hello World")
#
#
# ```
#
#
#
#
# 2. <mark>marking</mark>
#
#
#
#
#
# 3. <code> grey highlighting </code>

# %% [markdown]
# ### 5.4 Word type
# - **bold** / not bold<br>
# - <i>italic</i> or *italic*
# - LaTeX equation $y = ax + b$
# - Change word color
#     <span style="color:blue">some blue text</span>

# %% [markdown]
# ### Table
#
# | Welcome | to |
# | --- | --- |
# | Class | Comm4522 |
# | Good | Luck |

# %% [markdown]
# ### Image and link
# - images
#
# <img src="https://news.virginia.edu/sites/default/files/article_image/late_oct_grounds_09hr_da-1.jpg" style="width: 400px;"/>
#
# - links <br>
#
# [UVA Commerce School](https://www.commerce.virginia.edu/)

# %% [markdown]
# ## Exercise

# %% [markdown]
# <div style="background-color: #daffcd; border-left: 5px solid #b5ffc6; padding: 15px; margin-bottom: 20px; border-radius: 4px;">
# <b>Exercise: Create a Self-Introduction Notebook </b><br>
# Create a Jupyter Notebook to introduce yourself (e.g., name, name pronunciation, concentration, hobbies, hometown and countries traveled). Specifically, it should include Markdown cells with headers, bullet points, highlighting and online images, as well as code cells that allow people to input their name and hobbies.
#     </div>
