# %% [markdown]
# # Lab 01: Introduction

# %% [markdown]
# ## Jun Seo Lee | Section 1
#
# *Pronounced <mark>Joon-So Lee</mark>*
#
# ### **Concentration:**
# Information Technology
#
# ### **Track:**
# Analytics and AI

# %% [markdown]
# ### **Hometown:**
# Jakarta, Indonesia
#
# ### **Countries traveled:**
# - Asia
#     - Indonesia, South Korea, Japan, China, Thailand, Malaysia, Singapore, Philippines, Laos,
# - Europe
#     - UK, France, Switzerland, Germany, Austria, Czech Republic, Hungary
# - North America
#     - USA
#
# ### **Hobbies:**
# Soccer, Running, Hiking, Camping, Mahjong, Hwatu (Hanafuda)
#
# <img src="https://m.media-amazon.com/images/S/aplus-media-library-service-media/010d1cc3-69f1-4a59-b713-66c95d4b86a3.__CR0,0,970,600_PT0_SX970_V1___.jpg" style="width: 400px;"/>
#
# [My Personal GitHub](https://github.com/ethnicgarbage)

# %%
your_name = input("Enter your name: ")

print("Your name is: " + your_name)
# Out:
# Your name is:

# %%
your_hobby = input("Enter a hobby: ")

print("Your hobby is: " + your_name)
